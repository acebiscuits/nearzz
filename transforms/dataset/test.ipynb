# %%
import soundfile as sf

info = sf.info("./test_sounds/pets.wav")
print(info)                 # всё сразу
print(info.subtype)         # PCM_16 / PCM_24 / PCM_32 / FLOAT / DOUBLE
print(info.samplerate, info.channels)
# Out:
# ./test_sounds/pets.wav
# samplerate: 44100 Hz
# channels: 2
# duration: 16.000 s
# format: WAV (Microsoft) [WAV]
# subtype: Signed 16 bit PCM [PCM_16]
# PCM_16
# 44100 2
